# %%
# %run run.py

# %%
CXT.a = 3

# %%
CXT
# Out:
# Context: {'a': [3]}

# %%
CXT.a = 3

# %%
CXT.G = G

# %%
CXT
# Out:
# Context: {'a': [3, 3], 'G': [<networkx.classes.multigraph.MultiGraph object at 0x0000023C48E9B828>]}

# %%
G._repr_html_()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-c3cae8697eae> in <module>()
# ----> 1 G._repr_html_()
#
# AttributeError: 'MultiGraph' object has no attribute '_repr_html_'

# %%
G

# %%
# %matplotlib notebook

# %% [markdown]
# G

# %%
G

# %%
nx.draw(G)
# Out:
# <img src="data:image/png;base64,...">
